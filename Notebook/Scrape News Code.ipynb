# %% [markdown]
# # Scrape - Date Range

# %%
import pandas as pd
import os
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import re

# Buat direktori untuk menyimpan hasil scraping
os.makedirs('scraped_reports', exist_ok=True)

# Fungsi untuk membersihkan karakter ilegal dari teks
def clean_text(text):
    # Hapus karakter ilegal
    return re.sub(r'[\x00-\x1F\x7F-\x9F]', '', text)

# Fungsi untuk mengambil artikel di halaman utama
def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    articles = soup.find_all('article')

    titles, links, dates = [], [], []

    for article in articles:
        link = article.find('a')['href']
        title = article.find('h2').text.strip()

        # Ambil tanggal dari elemen dengan class yang sesuai
        date_tag = article.find('span', class_='date')
        date = date_tag.text.strip() if date_tag else 'No date found'

        titles.append(clean_text(title))  # Bersihkan judul
        links.append(link)
        dates.append(clean_text(date))  # Bersihkan tanggal

    return titles, links, dates

# Fungsi untuk mengambil konten artikel dan memperbarui tanggal
def fetch_news_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        date_div = soup.find('div', class_='text-cm text-gray')
        date_text = date_div.get_text(strip=True) if date_div else 'Tanggal tidak ditemukan'

        content_div = soup.find('div', class_='detail-text min-w-0')
        paragraphs = content_div.find_all('p') if content_div else []
        news_text = "\n".join(paragraph.get_text(strip=True) for paragraph in paragraphs)

        return clean_text(date_text), clean_text(news_text)  # Bersihkan teks artikel dan tanggal

    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return 'Error', 'Error'

# Simpan seluruh data ke dalam file Excel
def save_to_excel(df):
    df.to_excel('scraped_reports/scraped_articles.xlsx', index=False, engine='openpyxl')
    print(f'Saved all articles in scraped_articles.xlsx with {len(df)} articles')

# Fungsi untuk melakukan scraping berdasarkan tanggal dan jumlah halaman
def scrape_news_by_date(start_date, end_date, max_pages=5):
    all_data = []
    base_url = "https://www.cnbcindonesia.com/market/indeks/5"
    date_range = pd.date_range(start=start_date, end=end_date)

    for target_date in date_range:
        formatted_date = target_date.strftime("%Y/%m/%d")

        # Loop untuk setiap halaman
        for i in range(1, max_pages + 1):
            url = f"{base_url}/{i}?date={formatted_date}&tipe=artikel"
            titles, links, dates = scrape_page(url)

            # Ambil konten dari setiap artikel jika data tersedia
            for title, link, date in zip(titles, links, dates):
                article_date, content = fetch_news_content(link)

                if title and link and article_date and content:
                    all_data.append({
                        'Title': title,
                        'Link': link,
                        'Date': article_date,
                        'Content': content
                    })

    # Simpan semua data dalam satu file Excel
    if all_data:
        df = pd.DataFrame(all_data)
        save_to_excel(df)
        return df

# Mulai proses scraping
start_date = datetime.strptime("2025/01/01", "%Y/%m/%d")
end_date = datetime.strptime("2025/01/31", "%Y/%m/%d")

scrape_news_by_date(start_date, end_date, max_pages=5)
# Out:
# Error fetching https://www.cnbcindonesia.com/market/20250122080826-17-605011/optimis-tinggi-dirut-bbri-sunarso-borong-210000-saham-perusahaan: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Saved all articles in scraped_articles.xlsx with 855 articles
#                                                  Title  \
# 0    KRL Diserbu! Jumlah Penumpang Tembus 1,2 Juta ...
# 1    Pengawasan Aset Kripto Bakal Dipindah ke OJK, ...
# 2    Ini Gaji Terkecil dan Batas Usia Pay Later, At...
# 3      8 Kripto Ini Bakal Jadi Primadona di Tahun 2025
# 4    Dukung Ekonomi RI, Simak 10 Pencapaian BRI di ...
# ..                                                 ...
# 850             Bos BRI (BBRI) Kasih Bocoran Laba 2024
# 851   Bos Asuransi Curhat: Bisnisnya Kalah Sama Pinjol
# 852              Diam-Diam Asing Banyak Jual Saham Ini
# 853  Wamen BUMN Beri Kabar Terbaru Pembahasan RUU BUMN
# 854  BRI (BBRI) Hapus Utang 69.000 UMKM, NIlainya R...
#
#                                                   Link                   Date  \
# 0    https://www.cnbcindonesia.com/market/202501012...  01 January 2025 21:50
# 1    https://www.cnbcindonesia.com/market/202501012...  01 January 2025 21:37
# 2    https://www.cnbcindonesia.com/market/202501011...  01 January 2025 16:30
# 3    https://www.cnbcindonesia.com/market/202501011...  01 January 2025 15:45
# 4    https://www.cnbcindonesia.com/market/202501011...  01 January 2025 15:18
# ..                                                 ...                    ...
# 850  https://www.cnbcindonesia.com/market/202501310...  31 January 2025 07:50
# 851  https://www.cnbcindonesia.com/market/202501310...  31 January 2025 07:30
# 852  https://www.cnbcindonesia.com/market/202501310...  31 January 2025 07:10
# 853  https://www.cnbcindonesia.com/market/202501301...  31 January 2025 06:50
# 854  https://www.cnbcindonesia.com/market/202501310...  31 January 2025 06:35
#
#                                                Content
# 0    Jakarta, CNBC Indonesia -Penumpang angkutan ke...
# 1    Jakarta, CNBC Indonesia-Asosiasi Pedagang Aset...
# 2    Jakarta, CNBC Indonesia- Otoritas Jasa Keuanga...
# 3    Jakarta, CNBC Indonesia -Mata uang kripto (cry...
# 4    Jakarta, CNBC Indonesia- PT Bank Rakyat Indone...
# ..                                                 ...
# 850  Jakarta, CNBC Indonesia- Direktur Utama PT Ban...
# 851  Jakarta, CNBC Indonesia- Pertumbuhan industri ...
# 852  Jakarta, CNBC Indonesia- Indeks Harga Saham Ga...
# 853  Jakarta, CNBC Indonesia- Wakil Menteri Badan U...
# 854  Jakarta, CNBC Indonesia- PT Bank Rakyat Indone...
#
# [855 rows x 4 columns]

# %% [markdown]
# # Scrape - Specific Date

# %%
def scrape_news_by_specific_dates(dates, max_pages=5):
    all_data = []
    base_url = "https://www.cnbcindonesia.com/news/indeks/3"

    for target_date in dates:
        formatted_date = target_date.strftime("%d/%m/%Y")

        # Loop untuk setiap halaman
        for i in range(1, max_pages + 1):
            url = f"{base_url}?date={formatted_date}&tipe=artikel"
            titles, links, dates = scrape_page(url)

            # Ambil konten dari setiap artikel jika data tersedia
            for title, link, date in zip(titles, links, dates):
                article_date, content = fetch_news_content(link)

                if title and link and article_date and content:
                    all_data.append({
                        'Title': title,
                        'Link': link,
                        'Date': article_date,
                        'Content': content
                    })

    # Simpan semua data dalam satu file Excel
    if all_data:
        df = pd.DataFrame(all_data)
        save_to_excel(df)
        return df

# Tanggal spesifik yang ingin diambil datanya
specific_dates = [
    "01/09/2024"
]
# Konversi tanggal menjadi objek datetime
specific_dates = [datetime.strptime(date, "%d/%m/%Y") for date in specific_dates]

# Mulai proses scraping
scrape_news_by_specific_dates(specific_dates, max_pages=5)
# Out:
# Saved all articles in scraped_articles.xlsx with 50 articles
#                                                 Title  \
# 0   1 Juli 2025 Berubah, Cek Aturan Iuran & Denda ...
# 1   Siap-Siap Stasiun Karet Ditutup, Ini Alasan da...
# 2   RI Siaga Bencana! BMKG Warning Cuaca Ekstrem M...
# 3   Pertamina Amankan Pasokan LPG di Jakarta Selam...
# 4   Warga Palestina Lawan Rencana Relokasi Trump, ...
# 5   Banjir! Cek Kondisi Terbaru Lalu Lintas Arah B...
# 6   Tragedi Festival Keagamaan Terbesar Dunia, Sed...
# 7   Gempa Bumi M 5,1 Guncang Kolaka Sultra, Tak Be...
# 8   Pesawat Airbus Air Busan Terbakar di Bandara, ...
# 9   Cegah Kelangkaan, Pertamina Pasok 9 Juta Tabun...
# 10  1 Juli 2025 Berubah, Cek Aturan Iuran & Denda ...
# 11  Siap-Siap Stasiun Karet Ditutup, Ini Alasan da...
# 12  RI Siaga Bencana! BMKG Warning Cuaca Ekstrem M...
# 13  Pertamina Amankan Pasokan LPG di Jakarta Selam...
# 14  Warga Palestina Lawan Rencana Relokasi Trump, ...
# 15  Banjir! Cek Kondisi Terbaru Lalu Lintas Arah B...
# 16  Tragedi Festival Keagamaan Terbesar Dunia, Sed...
# 17  Gempa Bumi M 5,1 Guncang Kolaka Sultra, Tak Be...
# 18  Pesawat Airbus Air Busan Terbakar di Bandara, ...
# 19  Cegah Kelangkaan, Pertamina Pasok 9 Juta Tabun...
# 20  1 Juli 2025 Berubah, Cek Aturan Iuran & Denda ...
# 21  Siap-Siap Stasiun Karet Ditutup, Ini Alasan da...
# 22  RI Siaga Bencana! BMKG Warning Cuaca Ekstrem M...
# 23  Pertamina Amankan Pasokan LPG di Jakarta Selam...
# 24  Warga Palestina Lawan Rencana Relokasi Trump, ...
# 25  Banjir! Cek Kondisi Terbaru Lalu Lintas Arah B...
# 26  Tragedi Festival Keagamaan Terbesar Dunia, Sed...
# 27  Gempa Bumi M 5,1 Guncang Kolaka Sultra, Tak Be...
# 28  Pesawat Airbus Air Busan Terbakar di Bandara, ...
# 29  Cegah Kelangkaan, Pertamina Pasok 9 Juta Tabun...
# 30  1 Juli 2025 Berubah, Cek Aturan Iuran & Denda ...
# 31  Siap-Siap Stasiun Karet Ditutup, Ini Alasan da...
# 32  RI Siaga Bencana! BMKG Warning Cuaca Ekstrem M...
# 33  Pertamina Amankan Pasokan LPG di Jakarta Selam...
# 34  Warga Palestina Lawan Rencana Relokasi Trump, ...
# 35  Banjir! Cek Kondisi Terbaru Lalu Lintas Arah B...
# 36  Tragedi Festival Keagamaan Terbesar Dunia, Sed...
# 37  Gempa Bumi M 5,1 Guncang Kolaka Sultra, Tak Be...
# 38  Pesawat Airbus Air Busan Terbakar di Bandara, ...
# 39  Cegah Kelangkaan, Pertamina Pasok 9 Juta Tabun...
# 40  1 Juli 2025 Berubah, Cek Aturan Iuran & Denda ...
# 41  Siap-Siap Stasiun Karet Ditutup, Ini Alasan da...
# 42  RI Siaga Bencana! BMKG Warning Cuaca Ekstrem M...
# 43  Pertamina Amankan Pasokan LPG di Jakarta Selam...
# 44  Warga Palestina Lawan Rencana Relokasi Trump, ...
# 45  Banjir! Cek Kondisi Terbaru Lalu Lintas Arah B...
# 46  Tragedi Festival Keagamaan Terbesar Dunia, Sed...
# 47  Gempa Bumi M 5,1 Guncang Kolaka Sultra, Tak Be...
# 48  Pesawat Airbus Air Busan Terbakar di Bandara, ...
# 49  Cegah Kelangkaan, Pertamina Pasok 9 Juta Tabun...
#
#                                                  Link                   Date  \
# 0   https://www.cnbcindonesia.com/news/20250129132...  29 January 2025 13:45
# 1   https://www.cnbcindonesia.com/news/20250129112...  29 January 2025 13:15
# 2   https://www.cnbcindonesia.com/news/20250129104...  29 January 2025 12:30
# 3   https://www.cnbcindonesia.com/news/20250129111...  29 January 2025 11:24
# 4   https://www.cnbcindonesia.com/news/20250129093...  29 January 2025 10:45
# 5   https://www.cnbcindonesia.com/news/20250129095...  29 January 2025 10:06
# 6   https://www.cnbcindonesia.com/news/20250129094...  29 January 2025 09:51
# 7   https://www.cnbcindonesia.com/news/20250129085...  29 January 2025 08:55
# 8   https://www.cnbcindonesia.com/news/20250129061...  29 January 2025 06:20
# 9   https://www.cnbcindonesia.com/news/20250128192...  28 January 2025 21:45
# 10  https://www.cnbcindonesia.com/news/20250129132...  29 January 2025 13:45
# 11  https://www.cnbcindonesia.com/news/20250129112...  29 January 2025 13:15
# 12  https://www.cnbcindonesia.com/news/20250129104...  29 January 2025 12:30
# 13  https://www.cnbcindonesia.com/news/20250129111...  29 January 2025 11:24
# 14  https://www.cnbcindonesia.com/news/20250129093...  29 January 2025 10:45
# 15  https://www.cnbcindonesia.com/news/20250129095...  29 January 2025 10:06
# 16  https://www.cnbcindonesia.com/news/20250129094...  29 January 2025 09:51
# 17  https://www.cnbcindonesia.com/news/20250129085...  29 January 2025 08:55
# 18  https://www.cnbcindonesia.com/news/20250129061...  29 January 2025 06:20
# 19  https://www.cnbcindonesia.com/news/20250128192...  28 January 2025 21:45
# 20  https://www.cnbcindonesia.com/news/20250129132...  29 January 2025 13:45
# 21  https://www.cnbcindonesia.com/news/20250129112...  29 January 2025 13:15
# 22  https://www.cnbcindonesia.com/news/20250129104...  29 January 2025 12:30
# 23  https://www.cnbcindonesia.com/news/20250129111...  29 January 2025 11:24
# 24  https://www.cnbcindonesia.com/news/20250129093...  29 January 2025 10:45
# 25  https://www.cnbcindonesia.com/news/20250129095...  29 January 2025 10:06
# 26  https://www.cnbcindonesia.com/news/20250129094...  29 January 2025 09:51
# 27  https://www.cnbcindonesia.com/news/20250129085...  29 January 2025 08:55
# 28  https://www.cnbcindonesia.com/news/20250129061...  29 January 2025 06:20
# 29  https://www.cnbcindonesia.com/news/20250128192...  28 January 2025 21:45
# 30  https://www.cnbcindonesia.com/news/20250129132...  29 January 2025 13:45
# 31  https://www.cnbcindonesia.com/news/20250129112...  29 January 2025 13:15
# 32  https://www.cnbcindonesia.com/news/20250129104...  29 January 2025 12:30
# 33  https://www.cnbcindonesia.com/news/20250129111...  29 January 2025 11:24
# 34  https://www.cnbcindonesia.com/news/20250129093...  29 January 2025 10:45
# 35  https://www.cnbcindonesia.com/news/20250129095...  29 January 2025 10:06
# 36  https://www.cnbcindonesia.com/news/20250129094...  29 January 2025 09:51
# 37  https://www.cnbcindonesia.com/news/20250129085...  29 January 2025 08:55
# 38  https://www.cnbcindonesia.com/news/20250129061...  29 January 2025 06:20
# 39  https://www.cnbcindonesia.com/news/20250128192...  28 January 2025 21:45
# 40  https://www.cnbcindonesia.com/news/20250129132...  29 January 2025 13:45
# 41  https://www.cnbcindonesia.com/news/20250129112...  29 January 2025 13:15
# 42  https://www.cnbcindonesia.com/news/20250129104...  29 January 2025 12:30
# 43  https://www.cnbcindonesia.com/news/20250129111...  29 January 2025 11:24
# 44  https://www.cnbcindonesia.com/news/20250129093...  29 January 2025 10:45
# 45  https://www.cnbcindonesia.com/news/20250129095...  29 January 2025 10:06
# 46  https://www.cnbcindonesia.com/news/20250129094...  29 January 2025 09:51
# 47  https://www.cnbcindonesia.com/news/20250129085...  29 January 2025 08:55
# 48  https://www.cnbcindonesia.com/news/20250129061...  29 January 2025 06:20
# 49  https://www.cnbcindonesia.com/news/20250128192...  28 January 2025 21:45
#
#                                               Content
# 0   Jakarta, CNBC Indonesia -Menteri Kesehatan (Me...
# 1   Jakarta, CNBC Indonesia- Stasiun Karet akan di...
# 2   Jakarta, CNBC Indonesia- Kepala Badan Meteorol...
# 3   Jakarta, CNBC Indonesia- PT Pertamina Patra Ni...
# 4   Jakarta, CNBC Indonesia- Sejumlah warga Palest...
# 5   Jakarta, CNBC Indonesia- Sejumlah titik di wil...
# 6   Jakarta, CNBC Indonesia- Perayaan Kumbh Mela, ...
# 7   Jakarta, CNBC Indonesia- Gempa bumi dengan mag...
# 8   Jakarta, CNBC Indonesia- Sebuah pesawat Airbus...
# 9   Jakarta, CNBC Indonesia -PT Pertamina Patra Ni...
# 10  Jakarta, CNBC Indonesia -Menteri Kesehatan (Me...
# 11  Jakarta, CNBC Indonesia- Stasiun Karet akan di...
# 12  Jakarta, CNBC Indonesia- Kepala Badan Meteorol...
# 13  Jakarta, CNBC Indonesia- PT Pertamina Patra Ni...
# 14  Jakarta, CNBC Indonesia- Sejumlah warga Palest...
# 15  Jakarta, CNBC Indonesia- Sejumlah titik di wil...
# 16  Jakarta, CNBC Indonesia- Perayaan Kumbh Mela, ...
# 17  Jakarta, CNBC Indonesia- Gempa bumi dengan mag...
# 18  Jakarta, CNBC Indonesia- Sebuah pesawat Airbus...
# 19  Jakarta, CNBC Indonesia -PT Pertamina Patra Ni...
# 20  Jakarta, CNBC Indonesia -Menteri Kesehatan (Me...
# 21  Jakarta, CNBC Indonesia- Stasiun Karet akan di...
# 22  Jakarta, CNBC Indonesia- Kepala Badan Meteorol...
# 23  Jakarta, CNBC Indonesia- PT Pertamina Patra Ni...
# 24  Jakarta, CNBC Indonesia- Sejumlah warga Palest...
# 25  Jakarta, CNBC Indonesia- Sejumlah titik di wil...
# 26  Jakarta, CNBC Indonesia- Perayaan Kumbh Mela, ...
# 27  Jakarta, CNBC Indonesia- Gempa bumi dengan mag...
# 28  Jakarta, CNBC Indonesia- Sebuah pesawat Airbus...
# 29  Jakarta, CNBC Indonesia -PT Pertamina Patra Ni...
# 30  Jakarta, CNBC Indonesia -Menteri Kesehatan (Me...
# 31  Jakarta, CNBC Indonesia- Stasiun Karet akan di...
# 32  Jakarta, CNBC Indonesia- Kepala Badan Meteorol...
# 33  Jakarta, CNBC Indonesia- PT Pertamina Patra Ni...
# 34  Jakarta, CNBC Indonesia- Sejumlah warga Palest...
# 35  Jakarta, CNBC Indonesia- Sejumlah titik di wil...
# 36  Jakarta, CNBC Indonesia- Perayaan Kumbh Mela, ...
# 37  Jakarta, CNBC Indonesia- Gempa bumi dengan mag...
# 38  Jakarta, CNBC Indonesia- Sebuah pesawat Airbus...
# 39  Jakarta, CNBC Indonesia -PT Pertamina Patra Ni...
# 40  Jakarta, CNBC Indonesia -Menteri Kesehatan (Me...
# 41  Jakarta, CNBC Indonesia- Stasiun Karet akan di...
# 42  Jakarta, CNBC Indonesia- Kepala Badan Meteorol...
# 43  Jakarta, CNBC Indonesia- PT Pertamina Patra Ni...
# 44  Jakarta, CNBC Indonesia- Sejumlah warga Palest...
# 45  Jakarta, CNBC Indonesia- Sejumlah titik di wil...
# 46  Jakarta, CNBC Indonesia- Perayaan Kumbh Mela, ...
# 47  Jakarta, CNBC Indonesia- Gempa bumi dengan mag...
# 48  Jakarta, CNBC Indonesia- Sebuah pesawat Airbus...
# 49  Jakarta, CNBC Indonesia -PT Pertamina Patra Ni...
